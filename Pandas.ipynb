# %% [markdown]
# # Python - Explorando a biblioteca Pandas
#
# ## Pandas é uma biblioteca Python que fornece ferramentas de análise de dados e estruturas de dados de alta performance e fáceis de usar.![1_wP8ubuQEIrtxtfd-DTOTig.jpeg](attachment:1_wP8ubuQEIrtxtfd-DTOTig.jpeg)
#
# # -----------------------------------------------------------------------------------------------------------
#
# ### Vamos começar importando a Biblioteca.

# %%
import pandas as pd

# %% [markdown]
# ## Nesse notebook vamos usar os dados da Covid 19.
# ## o arquivo csv foi baixado na pagina https://covid.saude.gov.br/
#
# ![Covid-19.png](attachment:Covid-19.png)

# %% [markdown]
# ## Carregando nosso DataFrame

# %%
file = 'covid.csv'

# %%
dataset = pd.read_csv(file, sep=';', header=0)

# %% [markdown]
# ### Verificando os dados

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2130471 entries, 0 to 2130470
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   regiao                  object
#  1   estado                  object
#  2   municipio               object
#  3   coduf                   int64
#  4   codmun                  float64
#  5   codRegiaoSaude          float64
#  6   nomeRegiaoSaude         object
#  7   data                    object
#  8   semanaEpi               int64
#  9   populacaoTCU2019        float64
#  10  casosAcumulado          int64
#  11  casosNovos              int64
#  12  obitosAcumulado         int64
#  13  obitosNovos             int64
#  14  Recuperadosnovos        float64
#  15  emAcompanhamentoNovos   float64
#  16  interior/metropolitana  float64
# dtypes: float64(6), int64(6), object(5)
# memory usage: 276.3+ MB

# %%
dataset.head()
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2020-02-25          9       210147125.0               0           0
# 1  2020-02-26          9       210147125.0               1           1
# 2  2020-02-27          9       210147125.0               1           0
# 3  2020-02-28          9       210147125.0               1           0
# 4  2020-02-29          9       210147125.0               2           1
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# ...

# %%
dataset.tail()
# Out:
#                regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 2130466  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2130467  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2130468  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2130469  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2130470  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 2130466  DISTRITO FEDERAL  2021-04-05         14         3015268.0
# 2130467  DISTRITO FEDERAL  2021-04-06         14         3015268.0
# 2130468  DISTRITO FEDERAL  2021-04-07         14         3015268.0
# 2130469  DISTRITO FEDERAL  2021-04-08         14         3015268.0
# 2130470  DISTRITO FEDERAL  2021-04-09         14         3015268.0
#
#          casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# ...

# %%
dataset.shape
# Out:
# (2130471, 17)

# %% [markdown]
# ### Indexando a coluna 'data'

# %%
dataset.set_index('data', inplace=True)

# %%
dataset
# Out:
#                   regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# data
# 2020-02-25        Brasil    NaN       NaN     76       NaN             NaN
# 2020-02-26        Brasil    NaN       NaN     76       NaN             NaN
# 2020-02-27        Brasil    NaN       NaN     76       NaN             NaN
# 2020-02-28        Brasil    NaN       NaN     76       NaN             NaN
# 2020-02-29        Brasil    NaN       NaN     76       NaN             NaN
# ...                  ...    ...       ...    ...       ...             ...
# 2021-04-05  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2021-04-06  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2021-04-07  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2021-04-08  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2021-04-09  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
# ...

# %% [markdown]
# # Continua...
